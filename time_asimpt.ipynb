# %%
from matplotlib import pyplot as plt   
import re
N = []
for i in range(25):
    N.append(i+1)
lin = []
bin1 = []
wlin = []
wbin = []
slin = []
sbin = []
graf = []

# %%
lin = []
with open("lin_timeCB1.txt") as f:
    for line in f:
        lin.append((int(line)))
for x in lin:
    x = int(x)

# %%
bin1 = []
with open("bin_timeCB.txt") as f:
    for line in f:
        bin1.append((int(line)))
for x in bin1:
    x = int(x)

# %%
wlin = []
with open("worst_lin_timeCB.txt") as f:
    for line in f:
        wlin.append((int(line)))
for x in wlin:
    x = int(x)

# %%
wbin = []
with open("worst_bin_timeCB.txt") as f:
    for line in f:
        wbin.append((int(line)))
for x in wbin:
    x = int(x)

# %%
slin = []
with open("sum_lin_timeCB.txt") as f:
    for line in f:
        slin.append((int(line)))
for x in slin:
    x = int(x)

# %%
sbin = []
with open("sum_bin_timeCB.txt") as f:
    for line in f:
        sbin.append((int(line)))
for x in sbin:
    x = int(x)

# %%
from matplotlib import pyplot as plt
plt.scatter(N, lin)
plt.title('lin_time 10^(-6) sec')
# Out:
# Text(0.5, 1.0, 'lin_time 10^(-6) sec')

# %%
from matplotlib import pyplot as plt
plt.scatter(N, bin1)
plt.title('bin_time 10^(-9) sec')
# Out:
# Text(0.5, 1.0, 'bin_time 10^(-9) sec')

# %%
from matplotlib import pyplot as plt
plt.scatter(N, wlin)
plt.title('worst_lin_time 10^(-6) sec')
# Out:
# Text(0.5, 1.0, 'worst_lin_time 10^(-6) sec')

# %%
from matplotlib import pyplot as plt
plt.scatter(N, wbin)
plt.title('worst_bin_time 10^(-9) sec')
# Out:
# Text(0.5, 1.0, 'worst_bin_time 10^(-9) sec')

# %%
from matplotlib import pyplot as plt
plt.scatter([1, 2, 3, 4, 5], slin)
plt.title('sum_lin_time 10^(-6) sec')
# Out:
# Text(0.5, 1.0, 'sum_lin_time 10^(-6) sec')

# %%
from matplotlib import pyplot as plt
plt.scatter(N, sbin)
plt.title('sum_bin_time 10^(-9) sec')
# Out:
# Text(0.5, 1.0, 'sum_bin_time 10^(-9) sec')
